# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

from ood_plotting import plot_ood_scores

SAVE_PLOTS = True
#plt.rcParams['figure.figsize'] = [4,2.5]
plt.rcParams['figure.figsize'] = [4,2]

# %% [markdown]
# # Basic usage

# %%
# Generate scores for ID and OOD samples
id_data = np.random.normal(0,0.2,500)
ood_data = np.random.normal(0.4,0.1,500)

# Compute standard OOD metrics and plot histogram + threshold curve for AUTC
plot_ood_scores(id_data,ood_data)
# Out:
# {'aupr-in': 0.9243300719682965,
#  'aupr-out': 0.9612808140679628,
#  'auroc': 0.9429743589743589,
#  'fnr@95tnr': 0.352872294472144,
#  'fpr@95tpr': 0.1794871794871795,
#  'thresh_95tnr': 0.36121871572415887,
#  'thresh_95tpr': 0.24672994284276684}
# auFNR 0.5984, auFPR 0.1529
# --> AUTC 0.3757

# %% [markdown]
# # Introduction diagram (Fig. 1)

# %%
ood_data = np.load(f"synthetic_data/intro-1-ood.npy",allow_pickle=True)
id_data = np.load(f"synthetic_data/intro-1-id.npy",allow_pickle=True)

plot_ood_scores(id_data,ood_data,save=SAVE_PLOTS,plot_threshs=False,model_name="intro 2",plot_tight=False)

print(f"--------------------------------------------")

ood_data = np.load(f"synthetic_data/intro-2-ood.npy",allow_pickle=True)
id_data = np.load(f"synthetic_data/intro-2-id.npy",allow_pickle=True)

plot_ood_scores(id_data,ood_data,save=SAVE_PLOTS,plot_threshs=False,model_name="intro 1",plot_tight=False)
# Out:
# {'aupr-in': 0.988145458445435,
#  'aupr-out': 0.9921282044557126,
#  'auroc': 0.9899725274725275,
#  'fnr@95tnr': 0.03653846153846152,
#  'fpr@95tpr': 0.04047619047619048,
#  'thresh_95tnr': 0.4960777827482642,
#  'thresh_95tpr': 0.5076308289373958}
# auFNR 0.2650, auFPR 0.2764
# --> AUTC 0.2707
# --------------------------------------------
# {'aupr-in': 0.9850792337673626,
#  'aupr-out': 0.9862294511103855,
#  'auroc': 0.9854393654125128,
#  'fnr@95tnr': 0.07067049359793778,
#  'fpr@95tpr': 0.0718232044198895,
#  'thresh_95tnr': 0.5222422297844712,
#  'thresh_95tpr': 0.47653255075425177}
# auFNR 0.2122, auFPR 0.2049
# --> AUTC 0.2086

# %% [markdown]
# # Comparison of 9 imaginary models (Figs. 3,4,6,7)

# %%
for row in [1,2,3]:

    res = []
    for model in [1,2,3]:
        print(f"-------------- row {row}, model {model} --------------")
        id_data = np.load(f"synthetic_data/row{row}-{model}-id.npy",allow_pickle=True)
        ood_data = np.load(f"synthetic_data/row{row}-{model}-ood.npy",allow_pickle=True)

        res.append(plot_ood_scores(id_data,ood_data,save=SAVE_PLOTS,model_name=f"model {(row-1)*3+model}",return_metrics=True, plot_threshs=False))

    fig, axs = plt.subplots(1, 1, figsize=(2,2))
    for c in res:
        display = RocCurveDisplay.from_predictions(c["labels"], c["preds"],
                                      name=c["name"],ax=axs,linewidth=1,label=c["name"])

    axs.set_ylabel("True Positive Rate")
    axs.set_xlabel("False Positive Rate")
    axs.set_xticks([0, 0.5, 1])
    axs.set_yticks([0, 0.5, 1])
    plt.tight_layout(pad=0)

    if SAVE_PLOTS: plt.savefig(f"ood_plots/roc-curve-row{row}.pdf")

    plt.show()
# Out:
# -------------- row 1, model 1 --------------
# {'aupr-in': 1.0,
#  'aupr-out': 1.0,
#  'auroc': 1.0,
#  'fnr@95tnr': 0.9998054556492223,
#  'fpr@95tpr': 0.0,
#  'thresh_95tnr': 1.8999201296952495,
#  'thresh_95tpr': 0.47827835499632065}
# auFNR 0.0939, auFPR 0.0095
# --> AUTC 0.0517
# -------------- row 1, model 2 --------------
# {'aupr-in': 1.0,
#  'aupr-out': 1.0,
#  'auroc': 1.0,
#  'fnr@95tnr': 0.0,
#  'fpr@95tpr': 0.0,
#  'thresh_95tnr': 0.2867415872715807,
#  'thresh_95tpr': 0.34425899949575955}
# auFNR 0.5834, auFPR 0.2710
# --> AUTC 0.4272
# -------------- row 1, model 3 --------------
# {'aupr-in': 1.0,
#  'aupr-out': 1.0,
#  'auroc': 1.0,
#  'fnr@95tnr': 0.9990614047450649,
#  'fpr@95tpr': 0.0,
#  'thresh_95tnr': 1.8332486095906564,
#  'thresh_95tpr': 0.41804834237463917}
# auFNR 0.3873, auFPR 0.2021
# --> AUTC 0.2947
# -------------- row 2, model 1 --------------
# {'aupr-in': 0.9774035224384584,
#  'aupr-out': 0.9116394448948173,
#  'auroc': 0.9549029982363316,
#  'fnr@95tnr': 0.3051146384479718,
#  'fpr@95tpr': 0.159,
#  'thresh_95tnr': 0.055779573659318356,
#  'thresh_95tpr': 0.011282695430840541}
# auFNR 0.8556, auFPR 0.0093
# --> AUTC 0.4324
# -------------- row 2, model 2 --------------
# {'aupr-in': 0.9665274087000708,
#  'aupr-out': 0.9368961763972538,
#  'auroc': 0.9548931215597882,
#  'fnr@95tnr': 0.25889187027788646,
#  'fpr@95tpr': 0.1781781781781782,
#  'thresh_95tnr': 0.21176673140943658,
#  'thresh_95tpr': 0.06368839028695168}
# auFNR 0.6510, auFPR 0.0399
# --> AUTC 0.3454
# -------------- row 2, model 3 --------------
# {'aupr-in': 0.9769027436509992,
#  'aupr-out': 0.9062754520460887,
#  'auroc': 0.9548843198549658,
#  'fnr@95tnr': 0.262848456513481,
#  'fpr@95tpr': 0.1774891774891775,
#  'thresh_95tnr': 0.7245079988049127,
#  'thresh_95tpr': 0.3511865104384043}
# auFNR 0.2026, auFPR 0.1738
# --> AUTC 0.1882
# -------------- row 3, model 1 --------------
# {'aupr-in': 0.803598790597835,
#  'aupr-out': 0.8819474970766679,
#  'auroc': 0.8468178756747015,
#  'fnr@95tnr': 0.4628255940331024,
#  'fpr@95tpr': 0.6079664570230608,
#  'thresh_95tnr': 0.9469757918963987,
#  'thresh_95tpr': 0.3832482611686831}
# auFNR 0.1599, auFPR 0.4873
# --> AUTC 0.3236
# -------------- row 3, model 2 --------------
# {'aupr-in': 0.9269821652329491,
#  'aupr-out': 0.6394060644879428,
#  'auroc': 0.8468053173241853,
#  'fnr@95tnr': 0.8014354066985646,
#  'fpr@95tpr': 0.4634433962264151,
#  'thresh_95tnr': 0.8049538643957759,
#  'thresh_95tpr': 0.1641673185918659}
# auFNR 0.3982, auFPR 0.2405
# --> AUTC 0.3194
# -------------- row 3, model 3 --------------
# {'aupr-in': 0.8322847378060957,
#  'aupr-out': 0.85740497840102,
#  'auroc': 0.8468020100502511,
#  'fnr@95tnr': 0.5317848090307161,
#  'fpr@95tpr': 0.6261306532663317,
#  'thresh_95tnr': 0.5084820119003093,
#  'thresh_95tpr': 0.2744465624028867}
# auFNR 0.5056, auFPR 0.3135
# --> AUTC 0.4095
